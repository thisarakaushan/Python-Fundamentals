# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set_theme(style="darkgrid")

# %% [markdown]
# ### Dataset reading and basic Data Pre processing

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %% [markdown]
# # BAR

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,7))
plt.bar(df['parental level of education'],df['math score'])
# Out:
# <BarContainer object of 1000 artists>

# %%
import seaborn as sns
plt.subplots(figsize=(15,7))
sns.barplot(x='parental level of education', y='writing score',data=df)
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='writing score'>

# %%
import plotly.express as px
px.bar(df,x='race/ethnicity', y='reading score')
# Out:
# <div>                            <div id="5244aba3-c5dd-4f61-9e21-48e4e0855d3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5244aba3-c5dd-4f61-9e21-48e4e0855d3d")) {                    Plotly.newPlot(                        "5244aba3-c5dd-4f61-9e21-48e4e0855d3d",                        [{"alignmentgroup":"True","hovertemplate":"race/ethnicity=%{x}<br>reading score=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["group B","group C","group B","group A","group C","group B","group B","group B","group D","group B","group C","group D","group B","group A","group A","group C","group C","group B","group C","gro
# ...

# %% [markdown]
# # Histogram

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.subplots(figsize=(15,7))
plt.hist(df['reading score'])
# Out:
# (array([  4.,   7.,  22.,  64., 140., 182., 237., 168., 120.,  56.]),
#  array([ 17. ,  25.3,  33.6,  41.9,  50.2,  58.5,  66.8,  75.1,  83.4,
#          91.7, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.subplots(figsize=(15,7))
sns.histplot(df['reading score'])
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='Count'>

# %%
px.histogram(df['reading score'])
# Out:
# <div>                            <div id="058df3d5-fcec-4210-a2da-17b6441c197a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("058df3d5-fcec-4210-a2da-17b6441c197a")) {                    Plotly.newPlot(                        "058df3d5-fcec-4210-a2da-17b6441c197a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=reading score<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"reading score","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"reading score","offsetgroup":"reading score","orientation":"v","showlegend":true,"type":"histogram","x":[72,90,95,57,78,83,95,43,64,60,54,52,81,72,53,75,89,32,42,58,69,75,54,73,71,74,54,69,70,70,74,65,72,42,87,81,81,64,90,56,61,73,58,65,56,54,65,71,74,8
# ...

# %% [markdown]
# # Scatter

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.subplots(figsize=(15,7))
plt.scatter(df['reading score'],df['writing score'])

# %%
plt.subplots(figsize=(15,7))
sns.scatterplot(x='reading score',y='writing score',data = df)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='writing score'>

# %%
px.scatter(df,x='reading score',y='writing score')
# Out:
# <div>                            <div id="5222a1f4-085c-41d0-9cee-b8de77f40e1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5222a1f4-085c-41d0-9cee-b8de77f40e1e")) {                    Plotly.newPlot(                        "5222a1f4-085c-41d0-9cee-b8de77f40e1e",                        [{"hovertemplate":"reading score=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[72,90,95,57,78,83,95,43,64,60,54,52,81,72,53,75,89,32,42,58,69,75,54,73,71,74,54,69,70,70,74,65,72,42,87,81,81,64,90,56,61,73,58,65,56,54,65,71,74,84,55,69,44,78,84,41,85,55,59,17,74,39,61,80,58,64,37,72,58,64,63,55,51,57,49,41,26,78,74,68,49
# ...

# %% [markdown]
# # Boxplot

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.subplots(figsize=(15,7))
plt.boxplot(df['math score'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x238e5cbe7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x238e5cbeeb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x238e5cbe490>],
#  'medians': [<matplotlib.lines.Line2D at 0x238e5e5a5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x238e5e5a910>],
#  'means': []}

# %%
plt.subplots(figsize=(15,7))
sns.boxplot(y=df['math score'])
# Out:
# <AxesSubplot:ylabel='math score'>

# %%
px.box(df['math score'], points='all')
# Out:
# <div>                            <div id="1b4e04b2-a352-4ae3-829b-fc885126e6f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b4e04b2-a352-4ae3-829b-fc885126e6f0")) {                    Plotly.newPlot(                        "1b4e04b2-a352-4ae3-829b-fc885126e6f0",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"type":"box","x":["math score","math score","math score","math score","math score","math score","math score","math score","math score","math score","math score","math score","math score","math score","math score","math score","math score
# ...

# %% [markdown]
# # Distplot

# %%
plt.subplots(figsize=(15,7))
sns.distplot(x=df['math score'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:ylabel='Density'>

# %%
import plotly.figure_factory as ff


hist_data =[df['math score']]
group_labels = ['distplot'] # name of the dataset

fig = ff.create_distplot(hist_data, group_labels)
fig.show()
# Out:
# <div>                            <div id="9d284beb-4351-4d26-a35b-2935e4b841cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d284beb-4351-4d26-a35b-2935e4b841cb")) {                    Plotly.newPlot(                        "9d284beb-4351-4d26-a35b-2935e4b841cb",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"distplot","marker":{"color":"rgb(31, 119, 180)"},"name":"distplot","opacity":0.7,"type":"histogram","x":[72,69,90,47,76,71,88,40,64,38,58,40,65,78,50,69,88,18,46,54,66,65,44,69,74,73,69,67,70,62,69,63,56,40,97,81,74,50,75,57,55,58,53,59,50,65,55,66,57,82,53,77,53,88,71,33,82,52,58,0,79,39,62,69,59,67,45,60,61,39,58,63,41,61,49,44,30,80,61,62,47,49,50,72,42,73,76,71,58,73,65,27,71,43,79,78,65,63,58,
# ...

# %% [markdown]
# # violin plot

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.subplots(figsize=(15,7))
sns.violinplot(y=df['writing score'],x=df['race/ethnicity'])
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='writing score'>

# %%
px.violin(df,y='writing score',x='race/ethnicity', box=True, points="all")
# Out:
# <div>                            <div id="9c9e2f76-000a-48db-9afa-7ba7a97e6146" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c9e2f76-000a-48db-9afa-7ba7a97e6146")) {                    Plotly.newPlot(                        "9c9e2f76-000a-48db-9afa-7ba7a97e6146",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"race/ethnicity=%{x}<br>writing score=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","points":"all","scalegroup":"True","showlegend":false,"type":"violin","x":["group B","group C","group B","group A","group C","group B","group B","group B","group D","group B","group C","group D","group B","group A","group A","group C","group C","group B
# ...

# %% [markdown]
# # Pie Chart

# %%
y = np.array([35, 25, 25, 15])
plt.subplots(figsize=(15,7))
plt.pie(y)
plt.show()

# %%
px.pie(values=y)
# Out:
# <div>                            <div id="eb442479-32e4-4746-b7d6-4d765232afde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb442479-32e4-4746-b7d6-4d765232afde")) {                    Plotly.newPlot(                        "eb442479-32e4-4746-b7d6-4d765232afde",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"value=%{value}<extra></extra>","legendgroup":"","name":"","showlegend":false,"type":"pie","values":[35,25,25,15]}],                        {"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[
# ...

# %% [markdown]
# # Seaborn Special

# %% [markdown]
# ## Catplot

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.catplot(x="math score", y="parental level of education", data=df)

# %% [markdown]
# ## Swarm Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(figsize=(15,7)) 
ax = sns.swarmplot(x='race/ethnicity', y='math score', data=df)

plt.show()

# %% [markdown]
# ## Strip Plot

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
import seaborn as sns 
plt.subplots(figsize=(15,7))
sns.stripplot(x='gender', y='math score', data=df,
              jitter=True, hue='lunch', dodge=True)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %% [markdown]
# ## Boxen Plot

# %%
import seaborn as sns

plt.subplots(figsize=(15,7))
sns.boxenplot(x="race/ethnicity", y="math score",
              color="b", 
              scale="linear", data=df)
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='math score'>

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(df)

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %% [markdown]
# ## Count Plot

# %%
plt.subplots(figsize=(15,7))
sns.countplot(x='race/ethnicity', data=df)
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %% [markdown]
# ## Heatmap

# %%
plt.subplots(figsize=(15,7))
sns.heatmap(df.corr(),annot=True, linewidth=1, cmap='copper_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Subplot using Matplotlib and Seaborn

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_theme(style="darkgrid")
fig, axes = plt.subplots(3, 3, sharex=True, figsize=(16,8))
sns.countplot(ax=axes[0,0],x='gender',data = df)
sns.countplot(ax=axes[0,1],x='race/ethnicity',data = df)
sns.countplot(ax=axes[0,2],x='parental level of education',data = df)
sns.countplot(ax=axes[1,0],x='lunch',data = df)
sns.countplot(ax=axes[1,1],x='test preparation course',data = df)
sns.countplot(ax=axes[1,2],x='parental level of education',data = df)
sns.countplot(ax=axes[2,0],x='lunch',data = df)
sns.countplot(ax=axes[2,1],x='test preparation course', data=df)
sns.countplot(ax=axes[2,2],x='test preparation course', data=df)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='count'>

# %% [markdown]
# # Plotly

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### Stacked Histogram

# %%
px.histogram(df,x='reading score',color='lunch')
# Out:
# <div>                            <div id="e93842ef-b9af-4dcb-91b5-4cdf5b49250a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e93842ef-b9af-4dcb-91b5-4cdf5b49250a")) {                    Plotly.newPlot(                        "e93842ef-b9af-4dcb-91b5-4cdf5b49250a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"lunch=standard<br>reading score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"standard","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"standard","offsetgroup":"standard","orientation":"v","showlegend":true,"type":"histogram","x":[72,90,95,78,83,95,54,52,81,72,53,75,89,69,54,73,54,69,70,70,74,65,42,87,81,81,73,58,54,65,71,84,55,44,78,85,55,59,80,58,64,72,64,55,49,26,78,74,68,49,64,80,71,70,8
# ...

# %%
px.histogram(df,x='parental level of education', color='race/ethnicity')
# Out:
# <div>                            <div id="1a68a979-f2a2-4f2d-ac58-2d2be2d4e3c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a68a979-f2a2-4f2d-ac58-2d2be2d4e3c7")) {                    Plotly.newPlot(                        "1a68a979-f2a2-4f2d-ac58-2d2be2d4e3c7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"race/ethnicity=group B<br>parental level of education=%{x}<br>count=%{y}<extra></extra>","legendgroup":"group B","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"group B","offsetgroup":"group B","orientation":"v","showlegend":true,"type":"histogram","x":["bachelor's degree","master's degree","associate's degree","some college","some college","high school","high school","some high school","some co
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Stacked Box Plot

# %%
px.box(df,x='math score',color='parental level of education')
# Out:
# <div>                            <div id="c42598bf-413b-415f-af12-6b4042333760" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c42598bf-413b-415f-af12-6b4042333760")) {                    Plotly.newPlot(                        "c42598bf-413b-415f-af12-6b4042333760",                        [{"alignmentgroup":"True","hovertemplate":"parental level of education=bachelor's degree<br>math score=%{x}<extra></extra>","legendgroup":"bachelor's degree","marker":{"color":"#636efa"},"name":"bachelor's degree","notched":false,"offsetgroup":"bachelor's degree","orientation":"h","showlegend":true,"type":"box","x":[72,74,67,79,80,65,65,68,99,75,78,79,51,74,58,68,77,54,96,43,77,78,82,67,83,63,80,63,69,83,73,73,88,65,66,67,59,63,83,77,52,61,49,61,59,66,64,51,71,86,
# ...

# %% [markdown]
# ### Stacked Violin Plot

# %%
px.violin(df,y='math score',color='parental level of education', box=True, points='all')
# Out:
# <div>                            <div id="58795ed2-8630-437d-8328-0fc09d0ace50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58795ed2-8630-437d-8328-0fc09d0ace50")) {                    Plotly.newPlot(                        "58795ed2-8630-437d-8328-0fc09d0ace50",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"parental level of education=bachelor's degree<br>math score=%{y}<extra></extra>","legendgroup":"bachelor's degree","marker":{"color":"#636efa"},"name":"bachelor's degree","offsetgroup":"bachelor's degree","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"type":"violin","x0":" ","xaxis":"x","y":[72,74,67,79,80,65,65,68,99,75,78,79,51,74,58,68,77,54,96,43,77,78,82,67,83,63,80,63,
# ...

# %% [markdown]
# ### Stacked Distribution Plot

# %%
import plotly.figure_factory as ff
import numpy as np

# Add histogram data
x1 = df['math score']
x2 = df['reading score']
x3 = df['writing score']


# Group data together
hist_data = [x1, x2, x3]

group_labels = ['Group 1', 'Group 2', 'Group 3']

# Create distplot with custom bin_size
fig = ff.create_distplot(hist_data, group_labels, bin_size=.2)
fig.show()
# Out:
# <div>                            <div id="909f867c-4b1f-4203-bada-c440f34fbb28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("909f867c-4b1f-4203-bada-c440f34fbb28")) {                    Plotly.newPlot(                        "909f867c-4b1f-4203-bada-c440f34fbb28",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Group 1","marker":{"color":"rgb(31, 119, 180)"},"name":"Group 1","opacity":0.7,"type":"histogram","x":[72,69,90,47,76,71,88,40,64,38,58,40,65,78,50,69,88,18,46,54,66,65,44,69,74,73,69,67,70,62,69,63,56,40,97,81,74,50,75,57,55,58,53,59,50,65,55,66,57,82,53,77,53,88,71,33,82,52,58,0,79,39,62,69,59,67,45,60,61,39,58,63,41,61,49,44,30,80,61,62,47,49,50,72,42,73,76,71,58,73,65,27,71,43,79,78,65,63,58,65
# ...

# %% [markdown]
# # Bubble Chart

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
fig = px.scatter(df, x="math score", y="reading score",
	         size="writing score", color="parental level of education",
                 hover_name="race/ethnicity", log_x=True, size_max=60)

# %%
fig.show()
# Out:
# <div>                            <div id="e6f10ef0-3ca5-4ee8-9a40-5a4b05d47361" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6f10ef0-3ca5-4ee8-9a40-5a4b05d47361")) {                    Plotly.newPlot(                        "e6f10ef0-3ca5-4ee8-9a40-5a4b05d47361",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>parental level of education=bachelor's degree<br>math score=%{x}<br>reading score=%{y}<br>writing score=%{marker.size}<extra></extra>","hovertext":["group B","group D","group C","group E","group A","group C","group D","group D","group E","group B","group D","group C","group A","group D","group C","group D","group A","group D","group C","group C","group C","group B","group E","group B","group C","group D","group E","gro
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # plotly 3D world

# %%
px.scatter_3d(df, x='math score', y='reading score', z='writing score')
# Out:
# <div>                            <div id="5e26e16d-16cc-479a-8454-d7808546b080" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e26e16d-16cc-479a-8454-d7808546b080")) {                    Plotly.newPlot(                        "5e26e16d-16cc-479a-8454-d7808546b080",                        [{"hovertemplate":"math score=%{x}<br>reading score=%{y}<br>writing score=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"type":"scatter3d","x":[72,69,90,47,76,71,88,40,64,38,58,40,65,78,50,69,88,18,46,54,66,65,44,69,74,73,69,67,70,62,69,63,56,40,97,81,74,50,75,57,55,58,53,59,50,65,55,66,57,82,53,77,53,88,71,33,82,52,58,0,79,39,62,69,59,67,45,60,61,39,58,63,41,61,49
# ...

# %%
px.scatter_3d(df, x='math score', y='reading score', z='writing score', color='gender')
# Out:
# <div>                            <div id="b867dab8-5442-41de-acbe-e71626db17bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b867dab8-5442-41de-acbe-e71626db17bc")) {                    Plotly.newPlot(                        "b867dab8-5442-41de-acbe-e71626db17bc",                        [{"hovertemplate":"gender=female<br>math score=%{x}<br>reading score=%{y}<br>writing score=%{z}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"female","scene":"scene","showlegend":true,"type":"scatter3d","x":[72,69,90,71,88,38,65,50,69,18,54,65,69,67,62,69,63,56,74,50,75,58,53,50,55,66,57,71,33,82,0,69,59,60,39,58,41,61,62,47,73,76,71,58,73,65,79,63,58,65,85,58,87,52,70,77,51,99,75,78,51,55,79,88,87,5
# ...

# %%
px.scatter_3d(df, x='math score', y='reading score', z='writing score', color='race/ethnicity',symbol='gender')
# Out:
# <div>                            <div id="3dabc56e-a5fb-418b-a737-cab7e3330037" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3dabc56e-a5fb-418b-a737-cab7e3330037")) {                    Plotly.newPlot(                        "3dabc56e-a5fb-418b-a737-cab7e3330037",                        [{"hovertemplate":"race/ethnicity=group B<br>gender=female<br>math score=%{x}<br>reading score=%{y}<br>writing score=%{z}<extra></extra>","legendgroup":"group B, female","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"group B, female","scene":"scene","showlegend":true,"type":"scatter3d","x":[72,90,71,88,38,65,18,65,63,53,47,79,52,70,75,87,59,61,58,68,46,52,62,45,78,57,74,58,52,67,58,65,60,70,37,67,53,73,41,61,24,69,52,61,58,80,50,82,73,90,4
# ...
